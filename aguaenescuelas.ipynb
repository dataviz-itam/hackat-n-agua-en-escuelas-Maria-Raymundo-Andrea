# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: <object object at 0x00000156717ED0A0>
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('baseFinal.csv') 
data
# Out:
#      Nombre de la entidad Nombre del municipio o delegación  \
# 0          AGUASCALIENTES                    AGUASCALIENTES
# 1          AGUASCALIENTES                    AGUASCALIENTES
# 2          AGUASCALIENTES                    AGUASCALIENTES
# 3          AGUASCALIENTES                    AGUASCALIENTES
# 4          AGUASCALIENTES                    AGUASCALIENTES
# ...                   ...                               ...
# 6775            ZACATECAS                         ZACATECAS
# 6776            ZACATECAS                         ZACATECAS
# 6777            ZACATECAS                         ZACATECAS
# 6778            ZACATECAS                         ZACATECAS
# 6779            ZACATECAS                         ZACATECAS
#
#       Nombre del centro de trabajo Nombre del control (Público o Privado)  \
# 0      FRAY BARTOLOME DE LAS CASAS                                PÚBLICO
# 1                 JOSE VASCONCELOS                                PÚBLICO
# ...

# %%
print(data.dtypes)
# Out:
# Nombre de la entidad                                             object
# Nombre del municipio o delegación                                object
# Nombre del centro de trabajo                                     object
# Nombre del control (Público o Privado)                           object
# Parámetros biológicos y físicos (PBF): COLIFORMES FECALES       float64
# Parámetros biológicos y físicos (PBF): TURBIEDAD                float64
# Parámetros químicos (no metálicos) (PBQ): FLUORUROS             float64
# Parámetros químicos (no metálicos) (PBQ): NITRATOS              float64
# Parámetros químicos (no metálicos) (PBQ): SÓLIDOS DISUELTOS     float64
# Parámetros químicos metálicos (o metaloides) (PBM): ALUMINIO    float64
# Parámetros químicos metálicos (o metaloides) (PBM): ARSÉNICO    float64
# Parámetros químicos metálicos (o metaloides) (PBM): HIERRO      float64
# Parámetros químicos metálicos (o metaloides) (PBM): PLOMO       float64
# ...

# %%
selected_columns = ['Parámetros biológicos y físicos (PBF): COLIFORMES FECALES', 'Parámetros biológicos y físicos (PBF): TURBIEDAD','Parámetros químicos (no metálicos) (PBQ): FLUORUROS', 'Parámetros químicos (no metálicos) (PBQ): NITRATOS', 'Parámetros químicos (no metálicos) (PBQ): SÓLIDOS DISUELTOS', 'Parámetros químicos metálicos (o metaloides) (PBM): ARSÉNICO', 'Parámetros químicos metálicos (o metaloides) (PBM): HIERRO', 'Parámetros químicos metálicos (o metaloides) (PBM): PLOMO']
subset_data = data[selected_columns]
correlation_matrix = subset_data.corr(numeric_only=True)
print(correlation_matrix)
# Out:
#                                                     Parámetros biológicos y físicos (PBF): COLIFORMES FECALES  \
# Parámetros biológicos y físicos (PBF): COLIFORM...                                           1.000000
# Parámetros biológicos y físicos (PBF): TURBIEDAD                                             0.038029
# Parámetros químicos (no metálicos) (PBQ): FLUOR...                                          -0.426404
# Parámetros químicos (no metálicos) (PBQ): NITRATOS                                          -0.089389
# Parámetros químicos (no metálicos) (PBQ): SÓLID...                                          -0.135413
# Parámetros químicos metálicos (o metaloides) (P...                                           0.083475
# Parámetros químicos metálicos (o metaloides) (P...                                          -0.019223
# Parámetros químicos metálicos (o metaloides) (P...                                           0.114909
#
# ...

# %%
correlation_matrix = subset_data.corr(numeric_only=True)

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Mapa de Calor de Correlación')
plt.show()
